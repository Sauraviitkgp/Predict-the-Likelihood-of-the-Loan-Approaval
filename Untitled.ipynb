# %%
import numpy as np
import pandas as pd

# %%
test_data = pd.read_csv("dataset/test.csv",index_col=0)
train_data = pd.read_csv("dataset/train.csv")             # store the csv files in pandas data frame

# %%
target_train = train_data.target # Store output in target varible

# %%
test1 = test_data
train1 = train_data   # copy the file into another data frame

# %%
train1.shape
# Out:
# (108940, 166)

# %%
train1.head()
# Out:
#   APP_ID_C  target          var_d1  var_d2           var_d3         var_d4  \
# 0    app_1       0  Hit-6+ Vintage   816.0  RESIDENT INDIAN  Post-Graduate
# 1    app_2       0             NaN   841.0  RESIDENT INDIAN  Post-Graduate
# 2    app_3       0  Hit-6+ Vintage   791.0  RESIDENT INDIAN  Post-Graduate
# 3    app_4       0  Hit-6+ Vintage   821.0  RESIDENT INDIAN       Graduate
# 4    app_5       0  Hit-6+ Vintage   807.0  RESIDENT INDIAN       Graduate
#
#   var_d5           var_d6         var_d7 var_d8    ...      var_l_117  \
# 0      M  RESIDENT INDIAN  SELF-EMPLOYED      Y    ...            0.0
# 1      F  RESIDENT INDIAN       SALARIED      N    ...            0.0
# 2      M  RESIDENT INDIAN     PROPRIETOR      Y    ...            0.0
# 3      M  RESIDENT INDIAN  SELF-EMPLOYED      N    ...            0.0
# 4      M  RESIDENT INDIAN       SALARIED      Y    ...            0.0
#
#   var_l_118  var_l_119  var_l_120  var_l_121  var_l_122  var_l_123  var_l_124  \
# ...

# %% [markdown]
# # DATA PREPROCESSING

# %%
# Find No. of missing value and relplace it by mode of that missing values columns
train1.isna().sum()
# Out:
# APP_ID_C         0
# target           0
# var_d1       41105
# var_d2        6017
# var_d3        5799
# var_d4        1184
# var_d5        1181
# var_d6        1181
# var_d7        1748
# var_d8        1181
# var_d9           0
# var_d11          0
# var_b1           0
# var_b2           0
# var_b3           0
# var_b4           0
# var_b5           0
# var_b6           0
# var_b7           0
# var_b8           0
# var_b9           0
# var_b10          0
# var_b11          0
# var_b12          0
# var_b13          0
# var_b14          0
# var_b15          0
# var_b16          0
# var_b17          0
# var_b18          0
#              ...
# var_l_97         0
# var_l_98         0
# var_l_99         0
# var_l_100        0
# var_l_101        0
# var_l_102        0
# var_l_103        0
# var_l_104        0
# var_l_105        0
# var_l_106        0
# var_l_107        0
# var_l_108        0
# var_l_109        0
# var_l_110        0
# var_l_111        0
# var_l_112        0
# ...

# %%
# Replace the missing value with mode values of that column of train data set
train1['var_d1'] = train1['var_d1'].fillna(test1['var_d1'].mode()[0])
train1['var_d2'] = train1['var_d2'].fillna(test1['var_d2'].mode()[0])
train1['var_d3'] = train1['var_d3'].fillna(test1['var_d3'].mode()[0])
train1['var_d4'] = train1['var_d4'].fillna(test1['var_d4'].mode()[0])
train1['var_d5'] = train1['var_d5'].fillna(test1['var_d5'].mode()[0])
train1['var_d6'] = train1['var_d6'].fillna(test1['var_d6'].mode()[0])
train1['var_d7'] = train1['var_d7'].fillna(test1['var_d7'].mode()[0])
train1['var_d8'] = train1['var_d8'].fillna(test1['var_d8'].mode()[0])

# %% [markdown]
# # Covert string values into integers(Dummy value) using LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder # import label encoder from sklearn preprocessing

# %%
train1['var_d3'] = train1['var_d3'].astype('str')

# %%
train1.var_d3 = LabelEncoder().fit_transform(train1.var_d3)

# %%
train1['var_d1'] = train1['var_d1'].astype('str')

# %%
train1.var_d1 = LabelEncoder().fit_transform(train1.var_d1)

# %%
train1['var_d4'] = train1['var_d4'].astype('str')

# %%
train1.var_d4 = LabelEncoder().fit_transform(train1.var_d4)

# %%
train1['var_d5'] = train1['var_d5'].astype('str')

# %%
train1.var_d5 = LabelEncoder().fit_transform(train1.var_d5)

# %%
train1['var_d6'] = train1['var_d6'].astype('str')

# %%
train1.var_d6 = LabelEncoder().fit_transform(train1.var_d6)

# %%
train1['var_d7'] = train1['var_d7'].astype('str')

# %%
train1.var_d7 = LabelEncoder().fit_transform(train1.var_d7)

# %%
train1['var_d8'] = train1['var_d8'].astype('str')

# %%
train1.var_d8 = LabelEncoder().fit_transform(train1.var_d8)

# %%
train1['var_d11'] = train1['var_d11'].astype('str')

# %%
train1.var_d11 = LabelEncoder().fit_transform(train1.var_d11)

# %%
train1.head(10) #All string values converted into dummy variables
# Out:
#   APP_ID_C  var_d1  var_d2  var_d3  var_d4  var_d5  var_d6  var_d7  var_d8  \
# 0    app_1       0   816.0       5       2       1       9      70       1
# 1    app_2       0   841.0       5       2       0       9      65       0
# 2    app_3       0   791.0       5       2       1       9      55       1
# 3    app_4       0   821.0       5       0       1       9      70       0
# 4    app_5       0   807.0       5       0       1       9      65       1
# 5    app_6       0   788.0       5       1       1       9      65       0
# 6    app_7       0   779.0       5       0       1       9       6       1
# 7    app_8       0   801.0       5       2       1       9      64       0
# 8    app_9       0   815.0       5       0       0       9      55       1
# 9   app_10       0   804.0       5       0       1       9      55       0
#
#    var_d9    ...      var_l_117  var_l_118  var_l_119  var_l_120  var_l_121  \
# ...

# %% [markdown]
# #  Model training

# %%
del train1['target'] # Delete the output from train dataset
del train1['APP_ID_C'] # Delete the application id column

# %%
train1.shape
# Out:
# (108940, 164)

# %%
y = target_train # copy output to dataframe y

# %%
x = train1      # copy all relevent input into x

# %%
from sklearn.cross_validation import train_test_split   # split the training sample into train and test data
# Out:
# /home/saurav/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
X_train, X_test, y_train, y_test = train_test_split( x, y, test_size=0.30, random_state=42) #test_size=0.30,

# %% [markdown]
# # Apllied different classification standard model like- Decision Tree, Gradient Boosting , Xgboost, catboost

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
from xgboost import XGBClassifier

# %%
xgb = XGBClassifier()
DT = DecisionTreeClassifier()
GB = GradientBoostingClassifier()# By default learning_rate=0.1, n_estimators=100
GB1 = GradientBoostingClassifier(learning_rate=0.05, n_estimators=1000)

# %%
xgb.fit(X_train, y_train)   
dec.fit(X_train, y_train)
GB.fit(X_train, y_train)
GB1.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.05, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=1000,
#               presort='auto', random_state=None, subsample=1.0, verbose=0,
#               warm_start=False)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, xgb.predict(X_test)))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99     31972
#           1       0.85      0.02      0.05       710
#
# avg / total       0.98      0.98      0.97     32682
# /home/saurav/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
print(classification_report(y_test, dec.predict(X_test)))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.98      0.98      0.98     31972
#           1       0.11      0.12      0.11       710
#
# avg / total       0.96      0.96      0.96     32682

# %%
print(classification_report(y_test, GB.predict(X_test)))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99     31972
#           1       0.61      0.04      0.08       710
#
# avg / total       0.97      0.98      0.97     32682

# %%
print(classification_report(y_test, GB1.predict(X_test)))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99     31972
#           1       0.70      0.05      0.09       710
#
# avg / total       0.97      0.98      0.97     32682

# %%
test1.shape
# Out:
# (46688, 165)

# %% [markdown]
# # Preprocessing of test data

# %%
test1['var_d4'].mode()[0]
# Out:
# 'Graduate'

# %%
test1['var_d4'] = test1['var_d4'].fillna('Graduate')

# %%
test1['var_d1'] = test1['var_d1'].fillna(test1['var_d1'].mode()[0])

# %%
test1['var_d2'] = test1['var_d2'].fillna(test1['var_d2'].mode()[0])

# %%
test1['var_d3'] = test1['var_d3'].fillna(test1['var_d3'].mode()[0])

# %%
test1['var_d7'] = test1['var_d7'].fillna(test1['var_d7'].mode()[0])

# %%
test1['var_d5'] = test1['var_d5'].fillna(test1['var_d5'].mode()[0])

# %%
test1['var_d8'] = test1['var_d8'].fillna(test1['var_d8'].mode()[0])

# %%
test1['var_d6'] = test1['var_d6'].fillna(test1['var_d6'].mode()[0])

# %%
test1.isna().sum()
# Out:
# APP_ID_C     0
# var_d1       0
# var_d2       0
# var_d3       0
# var_d4       0
# var_d5       0
# var_d6       0
# var_d7       0
# var_d8       0
# var_d9       0
# var_d11      0
# var_b1       0
# var_b2       0
# var_b3       0
# var_b4       0
# var_b5       0
# var_b6       0
# var_b7       0
# var_b8       0
# var_b9       0
# var_b10      0
# var_b11      0
# var_b12      0
# var_b13      0
# var_b14      0
# var_b15      0
# var_b16      0
# var_b17      0
# var_b18      0
# var_b19      0
#             ..
# var_l_97     0
# var_l_98     0
# var_l_99     0
# var_l_100    0
# var_l_101    0
# var_l_102    0
# var_l_103    0
# var_l_104    0
# var_l_105    0
# var_l_106    0
# var_l_107    0
# var_l_108    0
# var_l_109    0
# var_l_110    0
# var_l_111    0
# var_l_112    0
# var_l_113    0
# var_l_114    0
# var_l_115    0
# var_l_116    0
# var_l_117    0
# var_l_118    0
# var_l_119    0
# var_l_120    0
# var_l_121    0
# var_l_122    0
# var_l_123    0
# ...

# %%
test1.var_d4 = LabelEncoder().fit_transform(test1.var_d4)
test1.var_d1 = LabelEncoder().fit_transform(test1.var_d1)
test1.var_d5 = LabelEncoder().fit_transform(test1.var_d5)

# %%
test1.var_d3 = LabelEncoder().fit_transform(test1.var_d3)
test1.var_d7 = LabelEncoder().fit_transform(test1.var_d7)
test1.var_d8 = LabelEncoder().fit_transform(test1.var_d8)
test1.var_d11 = LabelEncoder().fit_transform(test1.var_d11)
test1.var_d6 = LabelEncoder().fit_transform(test1.var_d6)

# %%
ID_orignal_test = test1.APP_ID_C

# %%
test1.shape
# Out:
# (46688, 165)

# %%
test1.dropna(inplace=True)

# %%
del test1['APP_ID_C']

# %%
test1.shape
# Out:
# (46688, 164)

# %% [markdown]
# # Prediction by different modal

# %%
pred_xgb = xgb.predict_proba(test1)

# %%
pred_GB = GB.predict_proba(test1)

# %%
pred_GB1 = GB1.predict_proba(test1)

# %%
pred_dec= dec.predict_proba(test1)

# %% [markdown]
# # Store the outcomes into csv files. All have same method . Therefore, I only done for Gradient Boosting modified parmeter

# %%
rlt = [0]*len(pred_GB1)
for i in range(len(pred_GB1)):
    rlt[i] = pred_GB1[i][1]

# %%
rlt
# Out:
# [0.013361634076619227,
#  0.0032912503634143437,
#  0.03512787080202263,
#  0.018156622847137698,
#  0.00786620939123407,
#  0.004998107985139462,
#  0.025112968949194847,
#  0.01055107500404313,
#  0.00786620939123407,
#  0.023129710417114552,
#  0.00026878012643791215,
#  0.01692466428976359,
#  0.03895548787061467,
#  0.01596492299315142,
#  0.001971302637551236,
#  0.05596892442905599,
#  0.020744026171432825,
#  0.01530418883020028,
#  0.00786620939123407,
#  0.03302141029355463,
#  0.010096999330968689,
#  0.002059905638413072,
#  0.006760172489289729,
#  0.003746692137319236,
#  0.017091170790224867,
#  0.028131482321936605,
#  0.021482529368918646,
#  0.013623821695148421,
#  0.0162065666757666,
#  0.008741817515142676,
#  0.011238191825252685,
#  0.0071304506659245325,
#  0.023114370783553027,
#  0.006615942568840288,
#  0.04734766354629606,
#  0.027246913044954454,
#  0.0023763178901172995,
#  0.006517018312765929,
#  0.008933853365343077,
#  0.0035186869819316775,
# ...

# %%
pred_GB1= pd.DataFrame({'target'
                           :rlt})

# %%
pred_GB1.head()
# Out:
#      target
# 0  0.013362
# 1  0.003291
# 2  0.035128
# 3  0.018157
# 4  0.007866

# %%
test1['APP_ID_C'] = ID_orignal_test
test1['target'] = pred_GB1

# %%
test1.head()
# Out:
#    var_d1  var_d2  var_d3  var_d4  var_d5  var_d6  var_d7  var_d8  var_d9  \
# 0       0    -1.0       5       2       1      10      51       1  -11111
# 1       0    -1.0       5       2       1      10      36       1       1
# 2       0    -1.0       5       0       0      10      51       1       1
# 3       0    -1.0       5       2       1      10      15       1  -11111
# 4       0    -1.0       5       1       2       8      56       1  -11111
#
#    var_d11    ...     var_l_119  var_l_120  var_l_121  var_l_122  var_l_123  \
# 0        0    ...      0.000000        0.0        0.0        0.0   0.000000
# 1        0    ...      0.000000        0.0        0.0        0.0   0.676471
# 2        0    ...      0.066667        0.0        0.0        0.0   0.220447
# 3        0    ...      0.000000        0.0        0.0        0.0   0.000000
# 4        0    ...      0.000000        0.0        0.0        0.0   0.000000
#
#    var_l_124  var_l_125  var_l_126    APP_ID_C    target
# ...

# %%
submission=test1[['APP_ID_C','target']]

# %%
submission.shape
# Out:
# (46688, 2)

# %%
submission.head()
# Out:
#      APP_ID_C    target
# 0  app_108941  0.013362
# 1  app_108942  0.003291
# 2  app_108943  0.035128
# 3  app_108944  0.018157
# 4  app_108945  0.007866

# %%
submission.to_csv('13th.csv', index=False)

# %%
# !pwd
# Out:
# /home/saurav/Desktop/ML Challenge/Axis_Intern challenge
